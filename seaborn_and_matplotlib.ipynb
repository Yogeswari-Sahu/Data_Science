# %% [markdown]
# # Excersise on various Visualization Techniques

# %% [markdown]
# The iris dataset contains measurements for 150 iris flowers from three different species.
#
#
# The three classes in the Iris dataset:
# Iris-setosa (n=50)
# Iris-versicolor (n=50)
# Iris-virginica (n=50)
# The four features of the Iris dataset:
# sepal length in cm
# sepal width in cm
# petal length in cm
# petal width in cm
#
#
# Get the data
# *Use seaborn to get the iris data by using: iris = sns.load_dataset('iris') *

# %% [raw]
# Import the necessary librairies for visualizing / plotting the graphs as shown below

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
iris=sns.load_dataset('iris')

# %%
sns.pairplot(data=iris,hue="species")

# %% [markdown]
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.

# %%
setosa = iris.loc[iris.species == "setosa"]
sns.kdeplot(setosa.sepal_width, setosa.sepal_length,cmap="Paired", shade=True, shade_lowest=False)

# %% [raw]
# # Use seaborn to get the tips data by using: tips = sns.load_dataset('tips') *

# %%
tips = sns.load_dataset('tips')
sns.set_style('ticks')
tips['tips_pct']=tips['tip']/tips['total_bill']*500
mp=sns.FacetGrid(tips,col = 'time',row = 'sex',margin_titles = True)
mp= mp.map(plt.hist,'tips_pct')

# %%
plt.figure(figsize=(4,5))
sns.boxplot('day','total_bill',data=tips,hue='sex',palette='seismic')
sns.despine()

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [raw]
# # Solve the following Questions using matplot library

# %%
import numpy as np
x=np.linspace(0,10,20)
y=x
fig=plt.figure()
axes=fig.add_axes([0.2,0.2,0.8,0.8])
axes.plot(x,y)
axes.legend(['linear'])

# %%
fig,ax=plt.subplots()
x=np.linspace(0,10,100)
ax.plot(x,np.sin(x))
ax.plot(x,np.cos(x),'--')

# %%
plt.subplot(1,2,1)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,8))
x=np.linspace(0,20,50)
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Normal scale")
axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.9,0.9])
axes.spines['right'].set_color('none')
axes.spines['top'].set_color('none')
axes.xaxis.set_ticks_position('bottom')
axes.spines['bottom'].set_position(('data',0))
axes.yaxis.set_ticks_position('left')
axes.spines['left'].set_position(('data',0))
x = np.linspace(-0.5, 1, 50)
axes.plot(x, x**5);
